# %% [markdown]
# # Deep face Library for face recognition

# %%
pip install deepface

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
import time
from datetime import date
from datetime import datetime
from IPython.display import Image, display

# %%
images= ["sachin_1.jpg", "sachin_2.jpg", "sachin_3.jpg", "sachin_4.jpg", "sachin_5.jpg", "sachin_6.jpg", "sachin_7.jpg"]

for image in images:
    display(Image(filename=image))

# %% [markdown]
# # Utility

# %%
def verify(img1_path, img2_path, model_name, detector_backend):
    img1= cv2.imread(img1_path)
    img2= cv2.imread(img2_path)
    
    #plt.imshow(img1[:,:,::-1])
    #plt.show()
    #plt.imshow(img2[:,:,::-1])
    #plt.show()
    output = DeepFace.verify(img1_path, img2_path, model_name, detector_backend=detector_backend)
    return output

# %%
image = "sachin_1.jpg"
imageset = ["sachin_2.jpg", "sachin_3.jpg", "sachin_4.jpg", "sachin_5.jpg", "sachin_6.jpg", "sachin_7.jpg", "sachin_8.jpeg", "sachin_9.jpg", "sachin_10.jpg", "sachin_11.jpeg"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace"]
detector_backends =  ["retinaface", "mtcnn", "opencv", "ssd"]

# %%
def form_matrix(image, imageset, models, detector_backends):
    f = open("data.txt", "w")
    f.write("Main Image\tImage to compare\tmodel\tdetector_backend\tTime elapsed\toutput\n")
    for model in models:
        for detector_backend in detector_backends:
            for image_from_set in imageset:
                print("processing ...... image  : ", image_from_set)
                try:
                    start = datetime.now()
                    op = verify(image,  image_from_set, model, detector_backend)
                    done = datetime.now()
                    elapsed = done - start
                    f.write(image+"\t"+image_from_set+"\t"+model+"\t"+detector_backend+"\t"+str(elapsed)+"\t"+str(op["verified"])+"\n")
                except:
                    print("error for image ", detector_backend)
                    pass
    f.close()
    print("processing completed ")

# %%
image = "sachin_17.jpg"
imageset = ["sachin_1.jpg"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace"]
detector_backends =  ["retinaface", "mtcnn", "opencv", "ssd"]

# %%
form_matrix(image, imageset, models, detector_backends)
# Out:
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# processing ...... image  :  sachin_1.jpg
# ...

# %% [markdown]
# # Different models

# %% [markdown]
# ## VGG-Face

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd

# %% [markdown]
# ###  opencv

# %%
print("================================ With VGG-Face Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "VGG-Face", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "VGG-Face", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "VGG-Face", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "VGG-Face", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "VGG-Face", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "VGG-Face", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With VGG-Face Model ===============================================
# {'verified': True, 'distance': 0.25966106228881836, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': False, 'distance': 0.43548726403319726, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.3274429374983261, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.30773488171967556, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.08087675852768128, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ### retinaface

# %%
print("================================ With VGG-Face Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "VGG-Face", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "VGG-Face", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "VGG-Face", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "VGG-Face", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "VGG-Face", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "VGG-Face", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With VGG-Face Model ===============================================
# {'verified': True, 'distance': 0.21345397234647412, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3708063707993914, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3259047715875887, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.29338283553422717, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.08254250117088147, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ### mtcnn

# %%
print("================================ With VGG-Face Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "VGG-Face", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "VGG-Face", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "VGG-Face", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "VGG-Face", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "VGG-Face", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "VGG-Face", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With VGG-Face Model ===============================================
# {'verified': True, 'distance': 0.18669602704834554, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3529907036178105, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.28000745026590523, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.2907584408863586, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.08354165220104026, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ### ssd

# %%
print("================================ With VGG-Face Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "VGG-Face", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "VGG-Face", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "VGG-Face", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "VGG-Face", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "VGG-Face", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "VGG-Face", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With VGG-Face Model ===============================================
# {'verified': True, 'distance': 0.18401743010821503, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.35827746169763885, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.28217680500606124, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.28623374493670006, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.06898465298231249, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ## Facenet

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd

# %% [markdown]
# #### opencv

# %%
print("================================ With Facenet Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "Facenet", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "Facenet", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "Facenet", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "Facenet", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "Facenet", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "Facenet", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With Facenet Model ===============================================
# {'verified': False, 'distance': 0.4661621861192652, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.4020491989074517, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.43029145480300324, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.4652763296503054, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.13469978549801176, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### retinaface

# %%
print("================================ With Facenet Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "Facenet", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "Facenet", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "Facenet", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "Facenet", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "Facenet", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "Facenet", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With Facenet Model ===============================================
# {'verified': True, 'distance': 0.3273060946671038, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.38782618372693944, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': False, 'distance': 0.43219185866987864, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.23618998116437417, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.1269955293722691, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### mtcnn

# %%
print("================================ With Facenet Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "Facenet", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "Facenet", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "Facenet", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "Facenet", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "Facenet", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "Facenet", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With Facenet Model ===============================================
# {'verified': False, 'distance': 0.40139831670692416, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.34912488354400795, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3735741253318129, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.252194642762702, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.15560908715245758, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### ssd

# %%
print("================================ With Facenet Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "Facenet", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "Facenet", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "Facenet", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "Facenet", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "Facenet", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "Facenet", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With Facenet Model ===============================================
# {'verified': False, 'distance': 0.45272878826055807, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.3883388850872892, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': False, 'distance': 0.4391582219677468, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.3429758423552337, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.1563483802060125, 'max_threshold_to_verify': 0.4, 'model': 'Facenet', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ## OpenFace

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd¶

# %% [markdown]
# #### opencv

# %%
print("================================ With OpenFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "OpenFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "OpenFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "OpenFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "OpenFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "OpenFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "OpenFace", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With OpenFace Model ===============================================
# {'verified': False, 'distance': 0.37259231572973806, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.8634692800375275, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 1.105276205429177, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.6677378177002518, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.4151386993927427, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# ####  retinaface

# %%
print("================================ With OpenFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "OpenFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "OpenFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "OpenFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "OpenFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "OpenFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "OpenFace", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With OpenFace Model ===============================================
# {'verified': False, 'distance': 0.4704313188788489, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.47141292596723516, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.5234350321381991, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.430005029649535, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.172354927479915, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# #### mtcnn

# %%
print("================================ With OpenFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "OpenFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "OpenFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "OpenFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "OpenFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "OpenFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "OpenFace", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With OpenFace Model ===============================================
# {'verified': False, 'distance': 0.38892317098414153, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.24209986755781532, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.3121449483132518, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.5704672992110347, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2217307654737345, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# #### ssd

# %%
print("================================ With OpenFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "OpenFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "OpenFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "OpenFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "OpenFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "OpenFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "OpenFace", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With OpenFace Model ===============================================
# {'verified': False, 'distance': 0.4235772838210736, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.36605042718631164, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.3680565154590678, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.3254818629742122, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.1406577718864287, 'max_threshold_to_verify': 0.1, 'model': 'OpenFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# ## DeepFace

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd

# %% [markdown]
# #### opencv

# %%
print("================================ With DeepFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepFace", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepFace Model ===============================================
# {'verified': True, 'distance': 0.21916245534121515, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.1915394025596996, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': False, 'distance': 0.24286471335744175, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2853460777389605, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.13712042067007624, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### retinaface

# %%
print("================================ With DeepFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepFace", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepFace Model ===============================================
# {'verified': False, 'distance': 0.2776851938230481, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2382215421045195, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.21574676784811753, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': False, 'distance': 0.24973127193200717, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.17080631328369222, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### mtcnn

# %%
print("================================ With DeepFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepFace", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepFace Model ===============================================
# {'verified': False, 'distance': 0.3141539798199128, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.24530194329734356, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2866314996318703, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2815255450518631, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.19444610264576778, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### ssd

# %%
print("================================ With DeepFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepFace", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepFace Model ===============================================
# {'verified': False, 'distance': 0.31763022802796737, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.263124943319492, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.25867615096375174, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.2812992173914013, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': True, 'distance': 0.14393576174862688, 'max_threshold_to_verify': 0.23, 'model': 'DeepFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# ## DeepID

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd

# %% [markdown]
# #### opencv

# %%
print("================================ With DeepID Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepID", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepID", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepID", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepID", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepID", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepID", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepID Model ===============================================
# {'verified': False, 'distance': 0.05964435603114193, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.05531587826514772, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.07556517223365522, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.09675932314768165, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.0317970775338986, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# #### retinaface

# %%
print("================================ With DeepID Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepID", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepID", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepID", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepID", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepID", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepID", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepID Model ===============================================
# {'verified': False, 'distance': 0.0797854881349711, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.0842048332464167, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.05001419294687359, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.09874070398798229, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.038717099480047645, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# #### mtcnn

# %%
print("================================ With DeepID Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepID", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepID", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepID", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepID", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepID", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepID", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepID Model ===============================================
# {'verified': False, 'distance': 0.08531046946955467, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.04538249196066979, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.08090047897446018, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.10706012002300458, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.03934561082023125, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# #### ssd

# %%
print("================================ With DeepID Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "DeepID", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "DeepID", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "DeepID", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "DeepID", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "DeepID", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "DeepID", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With DeepID Model ===============================================
# {'verified': False, 'distance': 0.07522612060368272, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.09133687733416229, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.0781591101150606, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.09157051298409558, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# {'verified': False, 'distance': 0.026461673641044348, 'max_threshold_to_verify': 0.015, 'model': 'DeepID', 'similarity_metric': 'cosine'}
# The are not same
# None
# ...

# %% [markdown]
# ## ArcFace

# %% [markdown]
# ### detector_backend : retinaface, mtcnn, opencv, ssd

# %% [markdown]
# #### opencv

# %%
print("================================ With ArcFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "ArcFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "ArcFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "ArcFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "ArcFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "ArcFace", "opencv"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "ArcFace", "opencv"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With ArcFace Model ===============================================
# {'verified': True, 'distance': 0.47141291709208566, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3796164545620768, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.3646041166517804, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.49147564098474605, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.16720045607193812, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### retinaface

# %%
print("================================ With ArcFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "ArcFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "ArcFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "ArcFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "ArcFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "ArcFace", "retinaface"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "ArcFace", "retinaface"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With ArcFace Model ===============================================
# {'verified': True, 'distance': 0.46543293634919114, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.39769920167427986, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.42809036832171155, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.44413126725779983, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.19193785623040727, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### mtcnn

# %%
print("================================ With ArcFace Model ===============================================")
start = datetime.now()
print(verify("sachin_1.jpg", "sachin_2.jpg", "ArcFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "ArcFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "ArcFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "ArcFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "ArcFace", "mtcnn"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "ArcFace", "mtcnn"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With ArcFace Model ===============================================
# {'verified': True, 'distance': 0.5063969836777269, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.4460465053428797, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.4686767021557895, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.40989605818367714, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.24308049463978265, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...

# %% [markdown]
# #### ssd

# %%
print("================================ With ArcFace Model ===============================================")

print(verify("sachin_1.jpg", "sachin_2.jpg", "ArcFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_3.jpg", "ArcFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_4.jpg", "ArcFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_5.jpg", "ArcFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_6.jpg", "ArcFace", "ssd"))
print(verify("sachin_1.jpg", "sachin_7.jpg", "ArcFace", "ssd"))
done = datetime.now()
elapsed = done - start
print("Time taken : ", elapsed.total_seconds())
# Out:
# ================================ With ArcFace Model ===============================================
# {'verified': True, 'distance': 0.5161788985715108, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.4635167908073089, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.47608440144700626, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.490252535220578, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# {'verified': True, 'distance': 0.2033479128420237, 'max_threshold_to_verify': 0.68, 'model': 'ArcFace', 'similarity_metric': 'cosine'}
# They are same
# None
# ...
